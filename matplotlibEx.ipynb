# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#https://www.listendata.com/2019/06/matplotlib-tutorial-learn-plot-python.html

# %%
#barplot

# %%
x = [1, 2, 3, 4, 5]
y = [5, 7, 3, 8, 4]
plt.bar(x,y)
plt.show()

# %%
plt.title("Simple Bar graph") # Name title of the graph
plt.xlabel('Students') # Assign the name of the x axis
plt.ylabel("Math Score") # Assign the name of the y axis
plt.bar(x, y, color='red') # Change bar color
plt.show()

# %%
barplot = plt.bar(x, y)
for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom') #va: vertical alignment y positional argument
    
plt.title("Simple Bar graph")
plt.xlabel('Students')
plt.ylabel("Math Score")
# Out:
# Text(0, 0.5, 'Math Score')

# %%
x = ['A', 'B', 'C', 'D', 'E']
y = [5, 7, 3, 8, 4]
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(range(len(x)), y)
plt.xticks(range(len(x)), x, size='small')
# Out:
# ([<matplotlib.axis.XTick at 0x7ff4a3565f60>,
#   <matplotlib.axis.XTick at 0x7ff4a356dba8>,
#   <matplotlib.axis.XTick at 0x7ff4a356db00>,
#   <matplotlib.axis.XTick at 0x7ff4a3522d30>,
#   <matplotlib.axis.XTick at 0x7ff4a34ae240>],
#  <a list of 5 Text xticklabel objects>)

# %%
plt.barh(x,y)
plt.title("Simple Horizontal Bar graph")
plt.xlabel("Math Score")
plt.ylabel('Students')
# Out:
# Text(0, 0.5, 'Students')

# %%
y,x = zip(*sorted(zip(y,x)))
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y)
ax=plt.subplot()
ax.invert_yaxis()
# Out:
# /home/srimugunthan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
print(plt.style.available)
# Out:
# ['_classic_test', 'seaborn-dark-palette', 'seaborn-colorblind', 'seaborn-darkgrid', 'seaborn-deep', 'fivethirtyeight', 'seaborn-whitegrid', 'seaborn-paper', 'ggplot', 'classic', 'dark_background', 'tableau-colorblind10', 'seaborn-muted', 'seaborn-bright', 'Solarize_Light2', 'seaborn-ticks', 'seaborn-poster', 'seaborn-notebook', 'seaborn-white', 'seaborn-pastel', 'seaborn-talk', 'fast', 'seaborn-dark', 'grayscale', 'seaborn', 'bmh']

# %%
plt.style.use('fivethirtyeight')

# %%
import pandas as pd

df = pd.DataFrame({"Year" : [2014,2015,2016,2017,2018], 
                  "Sales" : [2000, 3000, 4000, 3500, 6000]})

# %%
# plot line chart
plt.plot(df["Year"], df["Sales"])
plt.title("Simple Line Plot")
plt.xlabel('Year')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
ax = df.plot(x="Year", y="Sales", kind="line", title ="Simple Line Plot", legend=False, style = 'r--')
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"])
# Out:
# [Text(0, 0.5, 'Sales'),
#  [<matplotlib.axis.XTick at 0x7ff49ba05c50>,
#   <matplotlib.axis.XTick at 0x7ff49bd0c8d0>,
#   <matplotlib.axis.XTick at 0x7ff49b9df1d0>,
#   <matplotlib.axis.XTick at 0x7ff49b985160>,
#   <matplotlib.axis.XTick at 0x7ff49b985978>],
#  Text(0.5, 0, 'Year')]

# %%
ax.set_ylabel('Sales')
ax.set_xlabel('Year')
ax.set_xticks(df["Year"])
# Out:
# [<matplotlib.axis.XTick at 0x7ff49ba05c50>,
#  <matplotlib.axis.XTick at 0x7ff49bd0c8d0>,
#  <matplotlib.axis.XTick at 0x7ff49b9df1d0>,
#  <matplotlib.axis.XTick at 0x7ff49b985160>,
#  <matplotlib.axis.XTick at 0x7ff49b985978>]

# %%
ax.set_ylabel() plt.ylabel()
ax.set_xlabel() plt.xlabel()
ax.set_xticks() plt.xticks()
# Out:
#   File "<ipython-input-16-ca0455e26358>", line 1
#     ax.set_ylabel() plt.ylabel()
#                       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

product = pd.DataFrame({"Year" : [2014,2015,2016,2017,2018], 
                  "ProdASales" : [2000, 3000, 4000, 3500, 6000],
                  "ProdBSales" : [3000, 4000, 3500, 3500, 5500]})


# Multi line plot
ax = product.plot("Year", "ProdASales", kind="line", label = 'Product A Sales')
product.plot("Year", "ProdBSales", ax= ax , kind="line", label = 'Product B Sales', title= 'MultiLine Plot') #ax : axes object

# Set axes
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"])
# Out:
# [Text(0, 0.5, 'Sales'),
#  [<matplotlib.axis.XTick at 0x7ff49b941a20>,
#   <matplotlib.axis.XTick at 0x7ff49b9412b0>,
#   <matplotlib.axis.XTick at 0x7ff4a339f198>,
#   <matplotlib.axis.XTick at 0x7ff49b96c908>,
#   <matplotlib.axis.XTick at 0x7ff49b96ce48>],
#  Text(0.5, 0, 'Year')]

# %%
# How to show years with same interval as it is defined in column
ax = df.plot(x="Year", y="Sales", kind="line", title ="Simple Line Plot", legend=False)
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"])
# Out:
# [Text(0, 0.5, 'Sales'),
#  [<matplotlib.axis.XTick at 0x7ff49b9237f0>,
#   <matplotlib.axis.XTick at 0x7ff49b923b70>,
#   <matplotlib.axis.XTick at 0x7ff49b8c2d68>,
#   <matplotlib.axis.XTick at 0x7ff49b8d6b38>,
#   <matplotlib.axis.XTick at 0x7ff49b8e24e0>],
#  Text(0.5, 0, 'Year')]

# %%
ax = product.plot("Year", "ProdASales", kind='scatter', color = 'red', title = 'Year by ProductA Sales')
ax.set(ylabel='ProductA Sales', xlabel = 'Year', xticks =df["Year"])
plt.show()

# %%
share = [20, 12, 11, 4, 3]
companies = ['Google', 'Facebook', 'Apple', 'Microsoft', 'IBM', ]
comp = pd.DataFrame({"share" : share, "companies" : companies})
ax = comp.plot(y="share", kind="pie", labels = comp["companies"], autopct = '%1.0f%%', legend=False, title='Market Share')

# Hide y-axis label
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %%
# Customize Pie Chart
ax = comp.plot(y="share", kind="pie", labels = comp["companies"], startangle = 90, shadow = True, 
        explode = (0.1, 0.1, 0.1, 0, 0), autopct = '%1.0f%%', legend=False, title='Market Share')
ax.set(ylabel='')
plt.show()

# %%
# Creating random data
import numpy as np
np.random.seed(1)
mydf = pd.DataFrame({"Age" : np.random.randint(low=20, high=100, size=50)})

# Histogram
ax = mydf.plot(bins= 5, kind="hist", rwidth = 0.7, title = 'Distribution - Marks', legend=False)
ax.set(xlabel="Bins")
plt.show()

# %%
labels = ['Delhi', 'Mumbai', 'Bangalore', 'Chennai']
x1 = [45, 30, 15, 10]
x2 = [25, 20, 25, 50]

finaldf = pd.DataFrame({"2017_Score":x1, "2018_Score" : x2, "cities" : labels})

# %%
fig = plt.figure()

ax1 = fig.add_subplot(121)
ax = finaldf.plot(x="cities",  y="2017_Score", ax=ax1, kind="barh", legend = False, title = "2017 Score")
ax.invert_yaxis()

ax2 = fig.add_subplot(122)
ax = finaldf.plot(x="cities",  y="2018_Score", ax=ax2, kind="barh", legend = False, title = "2018 Score")
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %%
fig, (ax0, ax01) = plt.subplots(1, 2)

ax = finaldf.plot(x="cities",  y="2017_Score", ax=ax0, kind="barh", legend = False, title = "2017 Score")
ax.invert_yaxis()

ax = finaldf.plot(x="cities",  y="2018_Score", ax=ax01, kind="barh", legend = False, title = "2018 Score")
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %%
fig = plt.figure()
fig.add_subplot(121)
fig.add_subplot(122)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax = finaldf.plot(x="cities",  y="2017_Score", ax=ax1, kind="barh", legend = False, title = "2017 vs 2018 Score")
ax.invert_yaxis()
plt.xticks(range(0,60,10))
ax.set(ylabel='')

ax2 = fig.add_subplot(212)
ax = finaldf.plot(x="cities",  y="2018_Score", ax=ax2, kind="barh", legend = False)
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %%
# save plot
x = ['A','B','C', 'D']
y = [1,2,3,4]
fig = plt.figure()
plt.bar(x, y)
fig.savefig('./firstimg.png')
plt.close(fig)

# %%
x = ['A','B','C', 'D']
y = [100,119,800,900]
plt.bar(x, y)
ax = plt.subplot()
ax.set_ylim(0,1000)
plt.show()
# Out:
# /home/srimugunthan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
plt.bar(x, y)
plt.title("Cost of Living", fontsize=18, fontweight='bold', color='blue')
plt.xlabel("Cities", fontsize=16)
plt.ylabel("Score", fontsize=16)
# Out:
# Text(0, 0.5, 'Score')
